# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\srman\desktop\tendflow detection\tfodcourse\tfod1\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\srman\desktop\tendflow detection\tfodcourse\tfod1\lib\site-packages (from opencv-python) (1.24.4)

# %%
import cv2 
import uuid
import os
import time

# %%
labels = ['livelong']
number_imgs = 5

# %%
labels
# Out:
# ['livelong']

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    cv2.waitKey(1)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)        
        cv2.imshow('frame', frame)
        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for livelong
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting image 3
# Collecting image 4

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Collecting pyqt5
#   Downloading PyQt5-5.15.10-cp37-abi3-win_amd64.whl.metadata (2.2 kB)
# Collecting lxml
#   Downloading lxml-4.9.4-cp38-cp38-win_amd64.whl.metadata (3.8 kB)
# Collecting PyQt5-sip<13,>=12.13 (from pyqt5)
#   Downloading PyQt5_sip-12.13.0-cp38-cp38-win_amd64.whl.metadata (524 bytes)
# Collecting PyQt5-Qt5>=5.15.2 (from pyqt5)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#      ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#      ---------------------------------------- 0.1/50.1 MB 1.7 MB/s eta 0:00:29
#      ---------------------------------------- 0.3/50.1 MB 2.4 MB/s eta 0:00:21
#       --------------------------------------- 1.0/50.1 MB 5.7 MB/s eta 0:00:09
#      - -------------------------------------- 2.0/50.1 MB 9.1 MB/s eta 0:00:06
#      -- ------------------------------------- 3.3/50.1 MB 12.4 MB/s eta 0:00:04
#      ---- ----------------------------------- 6.1/50.1 MB 18.6 MB/s eta 0:00:03
#      ------ --------------------------------- 8.5/50.1 MB 21.7 MB/s eta 0:00:02
#      -------- ------------------------------ 10.7/50.1 MB 31.1 MB/s eta 0:00:02
#      -------- ------------------------------ 11.1/50.1 MB 29.7 MB/s eta 0:00:02
#      -------- ------------------------------ 11.4/50.1 MB 29.8 MB/s eta 0:00:02
#      --------- ----------------------------- 11.7/50.1 MB 26.2 MB/s eta 0:00:02
#      --------- ----------------------------- 12.1/50.1 MB 24.2 MB/s eta 0:00:02
#      --------- ----------------------------- 12.4/50.1 MB 21.8 MB/s eta 0:00:02
#      --------- ----------------------------- 12.5/50.1 MB 21.1 MB/s eta 0:00:02
#      --------- ----------------------------- 12.7/50.1 MB 19.2 MB/s eta 0:00:02
#      ---------- ---------------------------- 13.0/50.1 MB 17.2 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.2/50.1 MB 16.8 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.4/50.1 MB 16.0 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ---------- ---------------------------- 13.8/50.1 MB 14.9 MB/s eta 0:00:03
#      ----------- ---------------------------- 14.2/50.1 MB 7.9 MB/s eta 0:00:05
#      ------------- -------------------------- 16.3/50.1 MB 7.8 MB/s eta 0:00:05
#      -------------- ------------------------- 18.4/50.1 MB 7.9 MB/s eta 0:00:05
#      --------------- ------------------------ 19.0/50.1 MB 7.7 MB/s eta 0:00:05
#      --------------- ------------------------ 19.7/50.1 MB 7.5 MB/s eta 0:00:05
#      ---------------- ----------------------- 20.1/50.1 MB 7.4 MB/s eta 0:00:05
#      ---------------- ----------------------- 20.4/50.1 MB 7.1 MB/s eta 0:00:05
#      ---------------- ----------------------- 20.5/50.1 MB 6.9 MB/s eta 0:00:05
#      ---------------- ----------------------- 20.9/50.1 MB 6.8 MB/s eta 0:00:05
#      ---------------- ----------------------- 21.1/50.1 MB 6.7 MB/s eta 0:00:05
#      ---------------- ----------------------- 21.2/50.1 MB 6.7 MB/s eta 0:00:05
#      ----------------- ---------------------- 21.5/50.1 MB 6.6 MB/s eta 0:00:05
#      ----------------- ---------------------- 21.6/50.1 MB 6.5 MB/s eta 0:00:05
#      ----------------- ---------------------- 21.8/50.1 MB 6.5 MB/s eta 0:00:05
#      ----------------- ---------------------- 22.0/50.1 MB 6.4 MB/s eta 0:00:05
#      ----------------- ---------------------- 22.2/50.1 MB 6.2 MB/s eta 0:00:05
#      ----------------- ---------------------- 22.4/50.1 MB 6.2 MB/s eta 0:00:05
#      ------------------ --------------------- 22.7/50.1 MB 6.2 MB/s eta 0:00:05
#      ------------------ --------------------- 22.7/50.1 MB 6.1 MB/s eta 0:00:05
#      ------------------ --------------------- 22.9/50.1 MB 6.1 MB/s eta 0:00:05
#      ------------------ --------------------- 23.2/50.1 MB 6.1 MB/s eta 0:00:05
#      ------------------ --------------------- 23.6/50.1 MB 6.1 MB/s eta 0:00:05
#      ------------------- -------------------- 23.9/50.1 MB 6.1 MB/s eta 0:00:05
#      ------------------- -------------------- 24.1/50.1 MB 9.1 MB/s eta 0:00:03
#      ------------------- -------------------- 24.3/50.1 MB 9.0 MB/s eta 0:00:03
#      ------------------- -------------------- 24.5/50.1 MB 8.6 MB/s eta 0:00:03
#      ------------------- -------------------- 25.0/50.1 MB 8.5 MB/s eta 0:00:03
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.2/50.1 MB 8.3 MB/s eta 0:00:04
#      -------------------- ------------------- 25.5/50.1 MB 5.9 MB/s eta 0:00:05
#      --------------------- ------------------ 27.0/50.1 MB 5.7 MB/s eta 0:00:05
#      ---------------------- ----------------- 28.6/50.1 MB 5.7 MB/s eta 0:00:04
#      ----------------------- ---------------- 29.5/50.1 MB 5.7 MB/s eta 0:00:04
#      ------------------------ --------------- 30.4/50.1 MB 5.9 MB/s eta 0:00:04
#      ------------------------ --------------- 30.8/50.1 MB 6.0 MB/s eta 0:00:04
#      ------------------------- -------------- 31.6/50.1 MB 6.4 MB/s eta 0:00:03
#      -------------------------- ------------- 32.9/50.1 MB 7.6 MB/s eta 0:00:03
#      --------------------------- ----------- 34.7/50.1 MB 10.4 MB/s eta 0:00:02
#      ---------------------------- ---------- 36.4/50.1 MB 27.3 MB/s eta 0:00:01
#      ----------------------------- --------- 37.4/50.1 MB 24.2 MB/s eta 0:00:01
#      ------------------------------ -------- 39.0/50.1 MB 25.1 MB/s eta 0:00:01
#      ------------------------------- ------- 40.3/50.1 MB 25.1 MB/s eta 0:00:01
#      -------------------------------- ------ 41.4/50.1 MB 29.8 MB/s eta 0:00:01
#      --------------------------------- ----- 43.1/50.1 MB 31.2 MB/s eta 0:00:01
#      ---------------------------------- ---- 44.5/50.1 MB 31.1 MB/s eta 0:00:01
#      ------------------------------------ -- 46.3/50.1 MB 31.2 MB/s eta 0:00:01
#      ------------------------------------- - 48.2/50.1 MB 32.7 MB/s eta 0:00:01
#      --------------------------------------  49.7/50.1 MB 32.8 MB/s eta 0:00:01
#      --------------------------------------  49.9/50.1 MB 27.3 MB/s eta 0:00:01
#      --------------------------------------  50.1/50.1 MB 25.1 MB/s eta 0:00:01
#      --------------------------------------  50.1/50.1 MB 25.1 MB/s eta 0:00:01
#      --------------------------------------  50.1/50.1 MB 25.1 MB/s eta 0:00:01
#      --------------------------------------- 50.1/50.1 MB 19.8 MB/s eta 0:00:00
# Downloading PyQt5-5.15.10-cp37-abi3-win_amd64.whl (6.8 MB)
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/6.8 MB 11.2 MB/s eta 0:00:01
#    --- ------------------------------------ 0.6/6.8 MB 7.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.7/6.8 MB 6.7 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/6.8 MB 5.8 MB/s eta 0:00:01
#    ------- -------------------------------- 1.3/6.8 MB 5.2 MB/s eta 0:00:02
#    -------- ------------------------------- 1.4/6.8 MB 4.6 MB/s eta 0:00:02
#    -------- ------------------------------- 1.5/6.8 MB 4.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/6.8 MB 4.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.0/6.8 MB 4.6 MB/s eta 0:00:02
#    ------------- -------------------------- 2.4/6.8 MB 4.7 MB/s eta 0:00:01
#    -------------- ------------------------- 2.5/6.8 MB 4.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.8/6.8 MB 4.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.9/6.8 MB 4.4 MB/s eta 0:00:01
#    ------------------ --------------------- 3.2/6.8 MB 4.4 MB/s eta 0:00:01
#    -------------------- ------------------- 3.5/6.8 MB 4.4 MB/s eta 0:00:01
#    --------------------- ------------------ 3.7/6.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.8 MB 4.3 MB/s eta 0:00:01
#    ------------------------ --------------- 4.2/6.8 MB 4.4 MB/s eta 0:00:01
#    -------------------------- ------------- 4.5/6.8 MB 4.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.8/6.8 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 6.4/6.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.8 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.8/6.8 MB 5.5 MB/s eta 0:00:00
# Downloading lxml-4.9.4-cp38-cp38-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.9 MB 11.1 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.9 MB 14.2 MB/s eta 0:00:01
#    ------------------------------------- -- 3.6/3.9 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 15.6 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.13.0-cp38-cp38-win_amd64.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ------------------------------------ --- 71.7/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, lxml, pyqt5
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.13.0 lxml-4.9.4 pyqt5-5.15.10

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}
# Out:
# Cloning into 'Tensorflow\labelimg'...

# %%
if os.name == 'posix':
    # !cd make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py

# %%
TRAIN_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'train')
TEST_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'test')
ARCHIVE_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'archive.tar.gz')

# %%
# !tar -czf {ARCHIVE_PATH} {TRAIN_PATH} {TEST_PATH}
